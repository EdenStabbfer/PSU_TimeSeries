# %%
import os
from os import path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dirname = os.path.abspath(os.curdir) + r'/data/underwork/5/'

tsdf_c = pd.read_csv(path.join(os.sep, dirname, 'calm_p.csv'))
tsdf_c.set_index('Time').sort_index()

passangers = pd.read_csv('data/passengers.csv')
passangers = pd.read_csv('data/passengers.csv')
passangers.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
passangers.describe()
# Out:
#        Passengers
# count  144.000000
# mean   280.298611
# std    119.966317
# min    104.000000
# 25%    180.000000
# 50%    265.500000
# 75%    360.500000
# max    622.000000

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 10))

axs[0].plot(tsdf_c['1'])
axs[0].set_xlabel('Time')
axs[0].set_ylabel('mV')
axs[0].set_title('Покой. Время')

axs[1].plot(passangers['Passengers'])
axs[1].set_xlabel('Month')
axs[1].set_ylabel('Qty')
axs[1].set_title('Пассажиры')
# Out:
# Text(0.5, 1.0, 'Пассажиры')

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams
rcParams['figure.figsize'] = 15, 9

decompose = seasonal_decompose(passangers['Passengers'], period=12, model='Multiplicative')
decompose.plot()
plt.show()

# %%
decompose = seasonal_decompose(tsdf_c['5'], period=660)
decompose.plot()
plt.show()
